# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('titanic.csv')

# %%
data
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# Survived          0
# dtype: int64

# %%
data.columns.values
# Out:
# array(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'], dtype=object)

# %%
data = data.drop(['PassengerId', 'Name' , 'Ticket' , 'Cabin'],axis=1)
data
# Out:
#       Pclass     Sex   Age  SibSp  Parch      Fare Embarked  Survived
# 0          3    male  22.0      1      0    7.2500        S         0
# 1          1  female  38.0      1      0   71.2833        C         1
# 2          3  female  26.0      0      0    7.9250        S         1
# 3          1  female  35.0      1      0   53.1000        S         1
# 4          3    male  35.0      0      0    8.0500        S         0
# ...      ...     ...   ...    ...    ...       ...      ...       ...
# 1304       3    male   NaN      0      0    8.0500        S         0
# 1305       1  female  39.0      0      0  108.9000        C         1
# 1306       3    male  38.5      0      0    7.2500        S         0
# 1307       3    male   NaN      0      0    8.0500        S         0
# 1308       3    male   NaN      1      1   22.3583        C         0
#
# [1309 rows x 8 columns]

# %%
data['Age'].fillna(data.Age.median() , inplace =True)

# %%
data.Embarked.value_counts()
# Out:
# Embarked
# S    914
# C    270
# Q    123
# Name: count, dtype: int64

# %%
mean_fare= data.Fare.mean()
data.Fare.fillna(mean_fare, inplace = True)

# %%
mode_Embarked = data.Embarked.mode()[0]
data.Embarked.fillna(mode_Embarked, inplace = True)

# %%
median_age = data.Age.median()
data.Age.fillna(median_age, inplace = True)

# %%
data.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Survived    0
# dtype: int64

# %%
data.Sex.replace({
'male':1,
 'female':0
    } ,inplace =True)

# %%
data.tail()
# Out:
#       Pclass  Sex   Age  SibSp  Parch      Fare Embarked  Survived
# 1304       3    1  28.0      0      0    8.0500        S         0
# 1305       1    0  39.0      0      0  108.9000        C         1
# 1306       3    1  38.5      0      0    7.2500        S         0
# 1307       3    1  28.0      0      0    8.0500        S         0
# 1308       3    1  28.0      1      1   22.3583        C         0

# %%
data['Embarked_Q'] = (data.Embarked=='Q').astype(int)
data['Embarked_C'] = (data.Embarked=='C').astype(int)
data['Embarked_S'] = (data.Embarked=='S').astype(int)

# %%
data = data.drop('Embarked', axis=1)

# %%
data.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Survived  Embarked_Q  Embarked_C  \
# 0       3    1  22.0      1      0   7.2500         0           0           0
# 1       1    0  38.0      1      0  71.2833         1           0           1
# 2       3    0  26.0      0      0   7.9250         1           0           0
# 3       1    0  35.0      1      0  53.1000         1           0           0
# 4       3    1  35.0      0      0   8.0500         0           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %% [markdown]
# # Standaradization

# %%
mean_age = data['Age'].mean()
std_age = data['Age'].std()
data.Age = (data['Age']-mean_age)/std_age

# %%
mean_fare = data['Fare'].mean()
std_fare = data['Fare'].std()
data.Fare = (data['Fare']-mean_fare)/std_fare

# %%
mean_parch = data['Parch'].mean()
std_parch = data['Parch'].std()
data.Parch = (data['Parch']-mean_parch)/std_parch

# %%
mean_SibSp = data['SibSp'].mean()
std_SibSp = data['SibSp'].std()
data.SibSp = (data['SibSp']-mean_SibSp)/std_SibSp

# %%
data.head()
# Out:
#    Pclass  Sex       Age     SibSp     Parch      Fare  Survived  Embarked_Q  \
# 0       3    1 -0.581406  0.481104 -0.444829 -0.503402         0           0
# 1       1    0  0.658400  0.481104 -0.444829  0.734222         1           0
# 2       3    0 -0.271455 -0.478904 -0.444829 -0.490356         1           0
# 3       1    0  0.425937  0.481104 -0.444829  0.382778         1           0
# 4       3    1  0.425937 -0.478904 -0.444829 -0.487940         0           0
#
#    Embarked_C  Embarked_S
# 0           0           1
# 1           1           0
# 2           0           1
# 3           0           1
# 4           0           1

# %% [markdown]
# # Shuffle the data

# %%
scaled_data = data.copy()

# %%
suffled_indices =  np.arange(scaled_data.shape[0])
suffled_indices
# Out:
# array([   0,    1,    2, ..., 1306, 1307, 1308])

# %%
np.random.seed(333334)
np.random.shuffle(suffled_indices)
suffled_indices
# Out:
# array([928,   0, 878, ..., 253, 916,  54])

# %%
suffled_scaled_data = scaled_data.iloc[suffled_indices]

# %%
suffled_scaled_data.head()
# Out:
#      Pclass  Sex       Age     SibSp     Parch      Fare  Survived  \
# 928       3    0 -0.658894 -0.478904 -0.444829 -0.476102         1
# 0         3    1 -0.581406  0.481104 -0.444829 -0.503402         0
# 878       3    1 -0.116479 -0.478904 -0.444829 -0.490921         0
# 503       3    0  0.580912 -0.478904 -0.444829 -0.458224         0
# 103       3    1  0.270961 -0.478904 -0.444829 -0.476262         0
#
#      Embarked_Q  Embarked_C  Embarked_S
# 928           0           0           1
# 0             0           0           1
# 878           0           0           1
# 503           0           0           1
# 103           0           0           1

# %% [markdown]
# # Create Test set

# %%
test_ratio = 0.15
num_all_rows , num_cols = suffled_scaled_data.shape

# %%
num_test_rows = int(test_ratio *num_all_rows)
num_train_rows = int(num_all_rows - num_test_rows)

# %%
train_set = suffled_scaled_data[:num_train_rows]
test_set = suffled_scaled_data[num_train_rows:]

# %%
train_set.to_csv('final_train_set.csv')

# %%
test_set.to_csv('final_test_set.csv')
